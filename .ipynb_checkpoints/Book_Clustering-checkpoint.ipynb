# %%
import requests
import re
from bs4 import BeautifulSoup
import random
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %% [markdown]
# <h4>Scrape 100 Amazon Recommended Books to Read:</h4>

# %%
link = "https://www.amazon.com/b?ie=UTF8&node=8192263011"
html = requests.get(link).text
bs = BeautifulSoup(html,"html.parser")
books = []
for link in bs.find_all("span",{"class":"a-size-small"}):
    books.append(link.text)

# %%
print(len(books))
# Out:
# 100

# %% [markdown]
# <h4>Generate 5 Modified Books for each Book:</h4>

# %%
book_labels = []
modified_labels = []
modified_books = []
lbl = 0
for i in books: 
    token_book = i.split()
    word_len = len(token_book)
    book_labels.append(lbl)
    #Filter out books of length <= 2
    if len(token_book) > 2:
        for j in range(5): 
            random_start = random.randint(0,word_len-1)
            random_word_len = random.randint(2,word_len-1)
            if (random_start+random_word_len) > len(token_book[random_start:]): 
                b_start = token_book[random_start:]
                b_end = token_book[0:random_word_len - len(b_start)]
                b = b_start + b_end
            else: 
                b = token_book[random_start:(random_start+random_word_len)]
            modified_labels.append(lbl)
            modified_books.append(' '.join(b))
    lbl = lbl+1

# %%
print(len(modified_books))
# Out:
# 435

# %% [markdown]
# <h4>Put Together Our Clustering Dataset:</h4>

# %%
all_titles = books+modified_books
all_labels = book_labels+modified_labels
print(len(all_titles),"\n")
print(all_titles[0:100:20])
# Out:
# 535
#
# ['1984 (Signet Classics)', 'Diary of a Wimpy Kid, Book 1', 'Me Talk Pretty One Day', 'The Corrections: A Novel', 'The Poisonwood Bible: A Novel']

# %% [markdown]
# <h4>Pre-process Our Data:</h4>

# %%
def clean_data(raw_text): 
    letters = re.sub("[^a-zA-Z0-9]", " ",raw_text)                #Keeps only letters and numbers
    lower_case = letters.lower()                                  #Keeps all words lowercase
    tok = lower_case.split()                                      #Tokenizes
    stop_words = set(stopwords.words("english"))                  #Create set of stopwords
    wrds = [w for w in tok if w not in stop_words]                #Removes stopwords
    return(" ".join(wrds))

# %%
df_data = pd.DataFrame(all_titles,columns=['Book_Title'])
print(df_data.head(10))

#Apply cleaning function on dataframe 
df_data["cleaned_data"] = df_data["Book_Title"].apply(lambda i: clean_data(i))

#numpy array of cleaned data
cleaned_data = df_data["cleaned_data"].values
print("\n",cleaned_data[0:5])
# Out:
#                               Book_Title
# 0                 1984 (Signet Classics)
# 1                A Brief History of Time
# 2  A Heartbreaking Work of Staggering...
# 3   A Long Way Gone: Memoirs of a Boy...
# 4        The Bad Beginning: Or, Orphans!
# 5                      A Wrinkle in Time
# 6            Selected Stories, 1968-1994
# 7    Alice's Adventures in Wonderland...
# 8                All the President's Men
# 9               Angela's Ashes: A Memoir
#
#  ['1984 signet classics' 'brief history time'
#  'heartbreaking work staggering' 'long way gone memoirs boy'
#  'bad beginning orphans']

# %% [markdown]
# <h4>Generate tf-idf Features:</h4>

# %%
vectorizer = CountVectorizer(analyzer="word",tokenizer=None,preprocessor=None,stop_words=None)
vec_features = vectorizer.fit_transform(cleaned_data)  #The counts

# %%
X_counts = vec_features.toarray()
transformer = TfidfTransformer(smooth_idf=False)   #Create transformer
X_tfidf = transformer.fit_transform(X_counts)     #Fit transformer on the counts 
X_tfidf = X_tfidf.toarray()                       #numpy array of the tf-idf features

# %% [markdown]
# <h4>Optional - Dimensionality Reduction: PCA</h4>
# <p>If there is a very large  number of documents then the dimensionality of the features could be huge. To combat this, PCA can be used. With our data, the dimensionality is manageable so we do not need to use PCA but I leave this here in case the dataset is swapped out for a larger one. Please note that the X_tfidf in the following km.fit will need to be changed to red_dim_X_tfidf if PCA is used.</p>

# %%
components = 233
pca = PCA(n_components=components)
pca.fit(X_tfidf)
red_dim_X_tfidf = pca.transform(X_tfidf)

# %%
print(red_dim_X_tfidf.shape)
print(X_tfidf.shape)
# Out:
# (535, 233)
# (535, 238)

# %% [markdown]
# <h4>Create K-Means Object:</h4>

# %%
k = 100     #1 cluster for each book 
km = KMeans(n_clusters=k, init='k-means++', max_iter=100)
km.fit(X_tfidf)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=100, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
cluster_map = pd.DataFrame()
cluster_map['data_index'] = list(df_data["Book_Title"].values)
cluster_map['cluster'] = km.labels_

# %%
print(cluster_map.head(10))
# Out:
#                               data_index  cluster
# 0                 1984 (Signet Classics)       34
# 1                A Brief History of Time        2
# 2  A Heartbreaking Work of Staggering...       74
# 3   A Long Way Gone: Memoirs of a Boy...       66
# 4        The Bad Beginning: Or, Orphans!       11
# 5                      A Wrinkle in Time       51
# 6            Selected Stories, 1968-1994       79
# 7    Alice's Adventures in Wonderland...       26
# 8                All the President's Men       68
# 9               Angela's Ashes: A Memoir       21

# %% [markdown]
# <h4>Some Sample Cluster Values:</h4>

# %%
for i in range(100):
    print("Cluster", i,": \n",cluster_map[cluster_map.cluster == i],"\n")
# Out:
# Cluster 0 :
#             data_index  cluster
# 74   The Long Goodbye        0
# 420          The Long        0
# 421          The Long        0
# 422          The Long        0
# 423      Long Goodbye        0
# 424          The Long        0
#
# Cluster 1 :
#           data_index  cluster
# 56   The Book Thief        1
# 335        The Book        1
# 336      Book Thief        1
# 337      Book Thief        1
# 338       Thief The        1
# 339      Book Thief        1
# 398        (Book 1)        1
# 399    (Book 1) The        1
#
# Cluster 2 :
#                    data_index  cluster
# 1    A Brief History of Time        2
# 105          of Time A Brief        2
# 106        History of Time A        2
# 107    Brief History of Time        2
# 108          History of Time        2
# 109        History of Time A        2
# 129                  in Time        2
#
# Cluster 3 :
#             data_index  cluster
# 275  Novel Midnight's        3
# 276           A Novel        3
# 311           A Novel        3
# 313           A Novel        3
# 314           A Novel        3
# 357           A Novel        3
# 359       A Novel The        3
#
# Cluster 4 :
#        data_index  cluster
# 45   On the Road        4
# 83      The Road        4
# 290      Road On        4
# 291      Road On        4
# 292     the Road        4
#
# Cluster 5 :
#                                  data_index  cluster
# 28   Harry Potter and the Sorcerer's Stone        5
# 210                 Sorcerer's Stone Harry        5
# 211        Potter and the Sorcerer's Stone        5
# 212                            Stone Harry        5
# 213        Harry Potter and the Sorcerer's        5
# 214             the Sorcerer's Stone Harry        5
#
# Cluster 6 :
#                                             data_index  cluster
# 55              The Autobiography of Malcolm X: As...        6
# 330                      The Autobiography of Malcolm        6
# 331  Malcolm X: As... The Autobiography of Malcolm X:        6
# 332                           As... The Autobiography        6
# 333                              The Autobiography of        6
# 334                              The Autobiography of        6
#
# Cluster 7 :
#                data_index  cluster
# 49   Pride and Prejudice        7
# 305      Prejudice Pride        7
# 306            Pride and        7
# 307        and Prejudice        7
# 308        and Prejudice        7
# 309      Prejudice Pride        7
#
# Cluster 8 :
#                                 data_index  cluster
# 59   The Color of Water: A Black Man's...        8
# 350                 The Color of Water: A        8
# 352     Water: A Black Man's... The Color        8
# 353        Man's... The Color of Water: A        8
# 354          Man's... The Color of Water:        8
#
# Cluster 9 :
#                                 data_index  cluster
# 70   The Immortal Life of Henrietta Lacks        9
# 400            Lacks The Immortal Life of        9
# 401                    of Henrietta Lacks        9
# 402                   Henrietta Lacks The        9
# 403                    of Henrietta Lacks        9
# 404                  The Immortal Life of        9
#
# Cluster 10 :
#                          data_index  cluster
# 498                      The World       10
# 516  Story of... Unbroken: A World       10
# 517              Unbroken: A World       10
# 519              Unbroken: A World       10
#
# Cluster 11 :
#                            data_index  cluster
# 4    The Bad Beginning: Or, Orphans!       11
# 120                 Orphans! The Bad       11
# 121      Orphans! The Bad Beginning:       11
# 122          Beginning: Or, Orphans!       11
# 123                 Orphans! The Bad       11
# 124                          The Bad       11
#
# Cluster 12 :
#                        data_index  cluster
# 12                       Beloved       12
# 17               Charlotte's Web       12
# 22                Fahrenheit 451       12
# 24                     Gone Girl       12
# 25                Goodnight Moon       12
# 48           Portnoy's Complaint       12
# 50                 Silent Spring       12
# 64                     The Giver       12
# 85                   The Shining       12
# 86                  The Stranger       12
# 113              A Heartbreaking       12
# 142                      All the       12
# 157                   (P.S.) Bel       12
# 167                Club) Breath,       12
# 187  Greatly: How the Courage to       12
# 209                  Fates of...       12
# 224               Interpreter of       12
# 227           Smartest Kid on...       12
# 255        Newly Revised Edition       12
# 268               Me Talk Pretty       12
# 293                       On the       12
# 294                       On the       12
# 298                       Out of       12
# 299                       Out of       12
# 363                 Devil in the       12
# 366                         of a       12
# 377          Golden Compass: His       12
# 428               and the... The       12
# 457             and... The Power       12
# 459                   and... The       12
# 531                    Are Where       12
# 532                    Are Where       12
# 533                    Are Where       12
#
# Cluster 13 :
#                                              data_index  cluster
# 35            Little House on the Prairie (Full Color)       13
# 240  Prairie (Full Color) Little House on the Prair...       13
# 241               Prairie (Full Color) Little House on       13
# 242                 on the Prairie (Full Color) Little       13
# 243                           the Prairie (Full Color)       13
# 244                                (Full Color) Little       13
#
# Cluster 14 :
#                                            data_index  cluster
# 21                    Dune (Dune Chronicles, Book 1)       14
# 195                        1) Dune (Dune Chronicles,       14
# 196                                       Dune (Dune       14
# 197  Chronicles, Book 1) Dune (Dune Chronicles, Book       14
# 198                           (Dune Chronicles, Book       14
# 199  Chronicles, Book 1) Dune (Dune Chronicles, Book       14
#
# Cluster 15 :
#                         data_index  cluster
# 20   Diary of a Wimpy Kid, Book 1       15
# 190                   Kid, Book 1       15
# 191       Book 1 Diary of a Wimpy       15
# 192    Diary of a Wimpy Kid, Book       15
# 193     a Wimpy Kid, Book 1 Diary       15
# 194                  a Wimpy Kid,       15
#
# Cluster 16 :
#                                    data_index  cluster
# 52   Team of Rivals: The Political Genius...       16
# 315                Genius... Team of Rivals:       16
# 316      Political Genius... Team of Rivals:       16
# 317            Team of Rivals: The Political       16
# 318       of Rivals: The Political Genius...       16
# 319       of Rivals: The Political Genius...       16
#
# Cluster 17 :
#                     data_index  cluster
# 34   Life After Life: A Novel       17
# 235        Life After Life: A       17
# 236       After Life: A Novel       17
# 237       After Life: A Novel       17
# 238              A Novel Life       17
# 239             After Life: A       17
#
# Cluster 18 :
#                                            data_index  cluster
# 16                 Charlie and the Chocolate Factory       18
# 175                          Factory Charlie and the       18
# 176                        Charlie and the Chocolate       18
# 177                                  Charlie and the       18
# 178                    Chocolate Factory Charlie and       18
# 179  the Chocolate Factory Charlie and the Chocolate       18
#
# Cluster 19 :
#                    data_index  cluster
# 90   The Wind in the Willows       19
# 485                  Wind in       19
# 486     the Willows The Wind       19
# 487                 The Wind       19
# 488     the Willows The Wind       19
# 489                  Wind in       19
# 493              The Wind-Up       19
# 494        Novel The Wind-Up       19
#
# Cluster 20 :
#                    data_index  cluster
# 88   The Things They Carried       20
# 475             They Carried       20
# 476         They Carried The       20
# 477       Carried The Things       20
# 478         They Carried The       20
# 479         They Carried The       20
#
# Cluster 21 :
#                     data_index  cluster
# 9    Angela's Ashes: A Memoir       21
# 145           Angela's Ashes:       21
# 146         Angela's Ashes: A       21
# 147           Ashes: A Memoir       21
# 148           Memoir Angela's       21
# 149                  Ashes: A       21
# 409              A Memoir The       21
#
# Cluster 22 :
#                                     data_index  cluster
# 14   Breath, Eyes, Memory (Oprah's Book Club)       22
# 165        Breath, Eyes, Memory (Oprah's Book       22
# 166        Breath, Eyes, Memory (Oprah's Book       22
# 169        Breath, Eyes, Memory (Oprah's Book       22
#
# Cluster 23 :
#                          data_index  cluster
# 79   The Phantom Tollbooth 50th...       23
# 445              Phantom Tollbooth       23
# 446      Phantom Tollbooth 50th...       23
# 447          The Phantom Tollbooth       23
# 448              Tollbooth 50th...       23
# 449          Tollbooth 50th... The       23
#
# Cluster 24 :
#                         data_index  cluster
# 93   The Year of Magical Thinking       24
# 500           The Year of Magical       24
# 501             Thinking The Year       24
# 502     Magical Thinking The Year       24
# 503           of Magical Thinking       24
# 504                       Year of       24
#
# Cluster 25 :
#                                   data_index  cluster
# 80            The Poisonwood Bible: A Novel       25
# 450                       Poisonwood Bible:       25
# 451               Poisonwood Bible: A Novel       25
# 452                 The Poisonwood Bible: A       25
# 453                    Novel The Poisonwood       25
# 454  Bible: A Novel The Poisonwood Bible: A       25
#
# Cluster 26 :
#                                data_index  cluster
# 7    Alice's Adventures in Wonderland...       26
# 135                     in Wonderland...       26
# 136     Wonderland... Alice's Adventures       26
# 137          Adventures in Wonderland...       26
# 138          Adventures in Wonderland...       26
# 139     Wonderland... Alice's Adventures       26
#
# Cluster 27 :
#              data_index  cluster
# 130  Selected Stories,       27
# 132  Selected Stories,       27
# 133  Selected Stories,       27
#
# Cluster 28 :
#                                              data_index  cluster
# 44                  Of Human Bondage (Bantam Classics)       28
# 285                              Human Bondage (Bantam       28
# 286  Bondage (Bantam Classics) Of Human Bondage (Ba...       28
# 287                         (Bantam Classics) Of Human       28
# 288                              Human Bondage (Bantam       28
# 289                                   Of Human Bondage       28
#
# Cluster 29 :
#                         data_index  cluster
# 51   Slaughterhouse-Five: A Novel       29
# 310        Slaughterhouse-Five: A       29
# 312        Slaughterhouse-Five: A       29
#
# Cluster 30 :
#                     data_index  cluster
# 39   Man's Search for Meaning       30
# 260        Search for Meaning       30
# 261        Search for Meaning       30
# 262        Search for Meaning       30
# 263                Search for       30
# 264        Search for Meaning       30
#
# Cluster 31 :
#          data_index  cluster
# 29   In Cold Blood       31
# 215     Cold Blood       31
# 216       Blood In       31
# 217     Cold Blood       31
# 218       Blood In       31
# 219     Cold Blood       31
#
# Cluster 32 :
#                data_index  cluster
# 97   Valley of the Dolls       32
# 520      Dolls Valley of       32
# 521            the Dolls       32
# 522         Dolls Valley       32
# 523     the Dolls Valley       32
# 524         of the Dolls       32
#
# Cluster 33 :
#                               data_index  cluster
# 15   Catch-22: 50th Anniversary Edition       33
# 170                    50th Anniversary       33
# 171            50th Anniversary Edition       33
# 172              Edition Catch-22: 50th       33
# 173                      Catch-22: 50th       33
# 174            50th Anniversary Edition       33
#
# Cluster 34 :
#                   data_index  cluster
# 0    1984 (Signet Classics)       34
# 100          Classics) 1984       34
# 101          Classics) 1984       34
# 102          Classics) 1984       34
# 104          Classics) 1984       34
#
# Cluster 35 :
#                    data_index  cluster
# 30   Interpreter of Maladies       35
# 220              of Maladies       35
# 221     Maladies Interpreter       35
# 222              of Maladies       35
# 223              of Maladies       35
#
# Cluster 36 :
#          data_index  cluster
# 46   Out of Africa       36
# 295      of Africa       36
# 296      of Africa       36
# 297      of Africa       36
#
# Cluster 37 :
#                                   data_index  cluster
# 75   The Looming Tower: Al-Qaeda and the...       37
# 425             The Looming Tower: Al-Qaeda       37
# 426         Al-Qaeda and the... The Looming       37
# 427         Al-Qaeda and the... The Looming       37
# 429               the... The Looming Tower:       37
#
# Cluster 38 :
#             data_index  cluster
# 11   Bel Canto (P.S.)       38
# 155      Canto (P.S.)       38
# 156      Canto (P.S.)       38
# 158      Canto (P.S.)       38
# 159      Canto (P.S.)       38
#
# Cluster 39 :
#                  data_index  cluster
# 76   The Lord of the Rings       39
# 430          the Rings The       39
# 431       of the Rings The       39
# 432      Lord of the Rings       39
# 433         Rings The Lord       39
# 434                Lord of       39
#
# Cluster 40 :
#               data_index  cluster
# 26   Great Expectations       40
# 66     The Great Gatsby       40
# 380          Gatsby The       40
# 381           The Great       40
# 382           The Great       40
# 383        Great Gatsby       40
# 384          Gatsby The       40
#
# Cluster 41 :
#            data_index  cluster
# 82   The Right Stuff       41
# 460        The Right       41
# 461        The Right       41
# 462      Right Stuff       41
# 463        The Right       41
# 464        The Right       41
#
# Cluster 42 :
#                   data_index  cluster
# 63   The Fault in Our Stars       42
# 370      Fault in Our Stars       42
# 371                Fault in       42
# 372         Stars The Fault       42
# 373               The Fault       42
# 374     Our Stars The Fault       42
#
# Cluster 43 :
#                                              data_index  cluster
# 53              The Age of Innocence (Signet Classics)       43
# 103                                  (Signet Classics)       43
# 320                 Age of Innocence (Signet Classics)       43
# 321                                  Classics) The Age       43
# 322  of Innocence (Signet Classics) The Age of Inno...       43
# 323                              (Signet Classics) The       43
# 324                               Classics) The Age of       43
#
# Cluster 44 :
#                        data_index  cluster
# 89   The Very Hungry Caterpillar       44
# 480              The Very Hungry       44
# 481              The Very Hungry       44
# 482       Hungry Caterpillar The       44
# 483           Hungry Caterpillar       44
# 484              Caterpillar The       44
#
# Cluster 45 :
#              data_index  cluster
# 94   Things Fall Apart       45
# 505         Fall Apart       45
# 506         Fall Apart       45
# 507       Apart Things       45
# 508        Things Fall       45
# 509        Things Fall       45
# 530   Things Are Where       45
#
# Cluster 46 :
#                   data_index  cluster
# 40   Me Talk Pretty One Day       46
# 265                  Day Me       46
# 266             Day Me Talk       46
# 267                 One Day       46
# 269                  Day Me       46
#
# Cluster 47 :
#                                data_index  cluster
# 36   Lolita (Everyman's Library (Cloth))       47
# 247              Library (Cloth)) Lolita       47
# 248                     Library (Cloth))       47
#
# Cluster 48 :
#              data_index  cluster
# 18   Cutting for Stone       48
# 180      Stone Cutting       48
# 181        Cutting for       48
# 182      Stone Cutting       48
# 183          for Stone       48
# 184        Cutting for       48
#
# Cluster 49 :
#                          data_index  cluster
# 58          The Catcher in the Rye       49
# 345  in the Rye The Catcher in the       49
# 346                    The Catcher       49
# 347  in the Rye The Catcher in the       49
# 348                 The Catcher in       49
# 349                    The Catcher       49
#
# Cluster 50 :
#               data_index  cluster
# 87   The Sun Also Rises       50
# 470      Sun Also Rises       50
# 471           Rises The       50
# 472           Rises The       50
# 473      Also Rises The       50
# 474      Also Rises The       50
#
# Cluster 51 :
#              data_index  cluster
# 5    A Wrinkle in Time       51
# 125          A Wrinkle       51
# 126    Wrinkle in Time       51
# 127     Time A Wrinkle       51
# 128         Wrinkle in       51
#
# Cluster 52 :
#                                              data_index  cluster
# 41              Middlesex: A Novel (Oprah's Book Club)       52
# 168                                         Book Club)       52
# 270                   Middlesex: A Novel (Oprah's Book       52
# 271  Novel (Oprah's Book Club) Middlesex: A Novel (...       52
# 272                      Book Club) Middlesex: A Novel       52
# 273                                 Club) Middlesex: A       52
# 274                                   Club) Middlesex:       52
#
# Cluster 53 :
#                              data_index  cluster
# 71           The Liars' Club: A Memoir       53
# 405  Club: A Memoir The Liars' Club: A       53
# 406                         The Liars'       53
# 407                     Club: A Memoir       53
# 408                       Liars' Club:       53
#
# Cluster 54 :
#              data_index  cluster
# 73   The Little Prince       54
# 416      Little Prince       54
# 417      Little Prince       54
# 419         Prince The       54
#
# Cluster 55 :
#                        data_index  cluster
# 37   Love in the Time of Cholera       55
# 250              of Cholera Love       55
# 251          Love in the Time of       55
# 252          Cholera Love in the       55
# 253                   of Cholera       55
# 254             Love in the Time       55
#
# Cluster 56 :
#                                 data_index  cluster
# 57   The Brief Wondrous Life of Oscar Wao       56
# 340      The Brief Wondrous Life of Oscar       56
# 341                of Oscar Wao The Brief       56
# 342          Oscar Wao The Brief Wondrous       56
# 343        Wao The Brief Wondrous Life of       56
# 344                Wao The Brief Wondrous       56
#
# Cluster 57 :
#               data_index  cluster
# 84   The Secret History       57
# 465      Secret History       57
# 466          The Secret       57
# 467      Secret History       57
# 468          The Secret       57
# 469         History The       57
#
# Cluster 58 :
#                                 data_index  cluster
# 23   Fear and Loathing in Las Vegas: A...       58
# 200              Las Vegas: A... Fear and       58
# 201                             A... Fear       58
# 202              Fear and Loathing in Las       58
# 203      Loathing in Las Vegas: A... Fear       58
# 204                A... Fear and Loathing       58
#
# Cluster 59 :
#                data_index  cluster
# 72   The Lightning Thief       59
# 410        The Lightning       59
# 411      Lightning Thief       59
# 412        The Lightning       59
# 413        The Lightning       59
# 414      Lightning Thief       59
#
# Cluster 60 :
#                                 data_index  cluster
# 96   Unbroken: A World War II Story of...       60
# 515            A World War II Story of...       60
# 518                  A World War II Story       60
#
# Cluster 61 :
#                                  data_index  cluster
# 98   Where the Sidewalk Ends: The Poems...       61
# 526                     the Sidewalk Ends:       61
# 528        the Sidewalk Ends: The Poems...       61
# 529                     Ends: The Poems...       61
#
# Cluster 62 :
#                data_index  cluster
# 67   The Handmaid's Tale       62
# 385      Handmaid's Tale       62
# 386             Tale The       62
# 387       The Handmaid's       62
# 388       The Handmaid's       62
# 389      Handmaid's Tale       62
#
# Cluster 63 :
#                                  data_index  cluster
# 10   Are You There God? It's Me, Margaret.       63
# 150                  Me, Margaret. Are You       63
# 151           Margaret. Are You There God?       63
# 152                Margaret. Are You There       63
# 153                          Me, Margaret.       63
# 154                You There God? It's Me,       63
#
# Cluster 64 :
#                                   data_index  cluster
# 65   The Golden Compass: His Dark Materials       64
# 375                Golden Compass: His Dark       64
# 376                      Dark Materials The       64
# 378                      Dark Materials The       64
# 379                      His Dark Materials       64
#
# Cluster 65 :
#                                     data_index  cluster
# 19   Daring Greatly: How the Courage to Be...       65
# 185                           to Be... Daring       65
# 186                           Daring Greatly:       65
# 188                  to Be... Daring Greatly:       65
# 189                           to Be... Daring       65
#
# Cluster 66 :
#                                      data_index  cluster
# 3         A Long Way Gone: Memoirs of a Boy...       66
# 115                              of a Boy... A       66
# 116                        a Boy... A Long Way       66
# 117                Gone: Memoirs of a Boy... A       66
# 118  of a Boy... A Long Way Gone: Memoirs of a       66
# 119                   A Long Way Gone: Memoirs       66
#
# Cluster 67 :
#                                    data_index  cluster
# 33   Kitchen Confidential Updated Edition...       67
# 230                     Confidential Updated       67
# 231          Confidential Updated Edition...       67
# 232          Confidential Updated Edition...       67
# 233                       Updated Edition...       67
# 234                     Confidential Updated       67
#
# Cluster 68 :
#                    data_index  cluster
# 8    All the President's Men       68
# 140          President's Men       68
# 141      the President's Men       68
# 143              Men All the       68
# 144          President's Men       68
#
# Cluster 69 :
#                     data_index  cluster
# 68   The House at Pooh Corner       69
# 391        at Pooh Corner The       69
# 392            at Pooh Corner       69
# 393             House at Pooh       69
#
# Cluster 70 :
#                                  data_index  cluster
# 54   The Amazing Adventures of Kavalier...       70
# 326                     Amazing Adventures       70
# 328                  Amazing Adventures of       70
#
# Cluster 71 :
#               data_index  cluster
# 525        The Poems...       71
# 527  The Poems... Where       71
#
# Cluster 72 :
#                      data_index  cluster
# 62   The Diary of a Young Girl       72
# 365            of a Young Girl       72
# 367             Young Girl The       72
# 368            of a Young Girl       72
# 369       The Diary of a Young       72
#
# Cluster 73 :
#                         data_index  cluster
# 42   Midnight's Children: A Novel       73
# 277                   Children: A       73
# 278             Children: A Novel       73
# 279                   Children: A       73
#
# Cluster 74 :
#                                  data_index  cluster
# 2    A Heartbreaking Work of Staggering...       74
# 110                Work of Staggering... A       74
# 111                       of Staggering...       74
# 112                     of Staggering... A       74
# 114                     Heartbreaking Work       74
#
# Cluster 75 :
#           data_index  cluster
# 163  Born to Run: A       75
#
# Cluster 76 :
#                       data_index  cluster
# 207  and Steel: The Fates of...       76
# 208                  and Steel:       76
#
# Cluster 77 :
#                    data_index  cluster
# 31             Invisible Man       77
# 351             Man's... The       77
# 436                  The Man       77
# 439  The Man Who Mistook His       77
#
# Cluster 78 :
#                                   data_index  cluster
# 32   Jimmy Corrigan: The Smartest Kid on...       78
# 225                             on... Jimmy       78
# 226                             on... Jimmy       78
# 228                           Corrigan: The       78
# 229                   on... Jimmy Corrigan:       78
#
# Cluster 79 :
#                        data_index  cluster
# 6    Selected Stories, 1968-1994       79
# 131           Stories, 1968-1994       79
# 134           Stories, 1968-1994       79
#
# Cluster 80 :
#                                 data_index  cluster
# 47   Persepolis: The Story of a Childhood       80
# 300                           a Childhood       80
# 301              The Story of a Childhood       80
# 302               a Childhood Persepolis:       80
# 303                              Story of       80
# 304                  Story of a Childhood       80
#
# Cluster 81 :
#                                  data_index  cluster
# 81   The Power Broker: Robert Moses and...       81
# 455                Robert Moses and... The       81
# 456          Robert Moses and... The Power       81
# 458                           Moses and...       81
#
# Cluster 82 :
#                        data_index  cluster
# 245           Lolita (Everyman's       82
# 246  (Cloth)) Lolita (Everyman's       82
# 249   Lolita (Everyman's Library       82
#
# Cluster 83 :
#                     data_index  cluster
# 60   The Corrections: A Novel       83
# 355          The Corrections:       83
# 356            Corrections: A       83
# 358          The Corrections:       83
#
# Cluster 84 :
#                           data_index  cluster
# 13   Born to Run: A Hidden Tribe...       84
# 160            Hidden Tribe... Born       84
# 161     Run: A Hidden Tribe... Born       84
# 162                to Run: A Hidden       84
# 164           Born to Run: A Hidden       84
#
# Cluster 85 :
#                                             data_index  cluster
# 61             The Devil in the White City: Murder...       85
# 360                         the White City: Murder...       85
# 361  the White City: Murder... The Devil in the White       85
# 362                      City: Murder... The Devil in       85
# 364                     the White City: Murder... The       85
#
# Cluster 86 :
#                    data_index  cluster
# 325          Kavalier... The       86
# 327  Kavalier... The Amazing       86
# 329           of Kavalier...       86
#
# Cluster 87 :
#                  data_index  cluster
# 95   To Kill a Mockingbird       87
# 511                 Kill a       87
# 512              To Kill a       87
#
# Cluster 88 :
#                                 data_index  cluster
# 78   The Omnivore's Dilemma: A Natural...       88
# 440           A Natural... The Omnivore's       88
# 441             Dilemma: A Natural... The       88
# 442                      A Natural... The       88
# 443           A Natural... The Omnivore's       88
# 444             Dilemma: A Natural... The       88
#
# Cluster 89 :
#                        data_index  cluster
# 92   The World According to Garp       89
# 495            According to Garp       89
# 496       The World According to       89
# 497        According to Garp The       89
# 499          The World According       89
#
# Cluster 90 :
#             data_index  cluster
# 390  Corner The House       90
# 394  Corner The House       90
#
# Cluster 91 :
#                                data_index  cluster
# 91   The Wind-Up Bird Chronicle: A Novel       91
# 490                     The Wind-Up Bird       91
# 491                     The Wind-Up Bird       91
# 492               Novel The Wind-Up Bird       91
#
# Cluster 92 :
#                      data_index  cluster
# 69   The Hunger Games (Book 1)       92
# 395               Hunger Games       92
# 396           The Hunger Games       92
# 397         Games (Book 1) The       92
#
# Cluster 93 :
#                                 data_index  cluster
# 38   Love Medicine: Newly Revised Edition       93
# 256                        Love Medicine:       93
# 257        Revised Edition Love Medicine:       93
# 258                        Love Medicine:       93
# 259                  Love Medicine: Newly       93
#
# Cluster 94 :
#           data_index  cluster
# 510   a Mockingbird       94
# 513  Mockingbird To       94
# 514   a Mockingbird       94
#
# Cluster 95 :
#                                           data_index  cluster
# 77            The Man Who Mistook His Wife For A...       95
# 435                               His Wife For A...       95
# 437                           His Wife For A... The       95
# 438  Wife For A... The Man Who Mistook His Wife For       95
#
# Cluster 96 :
#                      data_index  cluster
# 99   Where the Wild Things Are       96
# 534         Are Where the Wild       96
#
# Cluster 97 :
#       data_index  cluster
# 415  The Little       97
# 418  The Little       97
#
# Cluster 98 :
#                                           data_index  cluster
# 43              Moneyball: The Art of Winning an...       98
# 280                              Moneyball: The Art       98
# 281                           Moneyball: The Art of       98
# 282                        Winning an... Moneyball:       98
# 283                        an... Moneyball: The Art       98
# 284  of Winning an... Moneyball: The Art of Winning       98
#
# Cluster 99 :
#                                    data_index  cluster
# 27   Guns, Germs, and Steel: The Fates of...       99
# 205              Guns, Germs, and Steel: The       99
# 206        of... Guns, Germs, and Steel: The       99

# %% [markdown]
# <h4>Performance - Purity:</h4>

# %%
def purity_score(clusters, classes):
    
    A = np.c_[(clusters,classes)]

    n_accurate = 0.

    for j in np.unique(A[:,0]):
        z = A[A[:,0] == j, 1]
        x = np.argmax(np.bincount(z))
        n_accurate += len(z[z == x])

    return n_accurate / A.shape[0]

# %%
print("Purity: ",purity_score(km.labels_,all_labels))
# Out:
# Purity:  0.9102803738317757
